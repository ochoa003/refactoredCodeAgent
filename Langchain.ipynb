# %% [markdown]
# # NIVEL 2: LANGCHAIN

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Carga tu API Key desde un archivo .env para seguridad
load_dotenv()

# Configuración del LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", 
    temperature=0.2
)

# Definición del Prompt (ChatPromptTemplate)
system_prompt = """
Eres un ingeniero de software senior experto en Clean Code y arquitectura de sistemas. 
Tu objetivo es analizar código y refactorizarlo priorizando la simplicidad (Monolito Modular).

Sigue esta Cadena de Pensamiento (CoT) paso a paso:
1. Análisis: Identifica la complejidad ciclomática del código entregado.
2. Evaluación: Detecta acoplamientos innecesarios o sobreingeniería.
3. Propuesta: Sugiere una estructura simplificada (Monolito Modular).
4. Refactorización: Entrega el código final con Docstrings (formato Google) y Type Hints.
"""

prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "Por favor revisa el siguiente código:\n{codigo_fuente}")
])

# Cadena usando LCEL (LangChain Expression Language)
cadena = prompt | llm | StrOutputParser()

# %%
# --- Demostración en tiempo real ---
if __name__ == "__main__":
    codigo_input = """
def sumar_lista(l):
    s = 0
    for i in l:
        s += i
    return s
"""
    print("Iniciando análisis del agente...\n")
    resultado = cadena.invoke({"codigo_fuente": codigo_input})
    print(resultado)
# Out:
# Iniciando análisis del agente...
#
# ¡Excelente! Analicemos este código como un ingeniero senior.
#
# ---
#
# ### 1. Análisis (Complejidad Ciclomática)
#
# *   **Función:** `sumar_lista`
# *   **Puntos de Decisión:** 1 (el bucle `for`)
# *   **Complejidad Ciclomática (CC):** 1 (puntos de decisión) + 1 (entrada/salida) = **2**
#
# **Conclusión:** Una complejidad ciclomática de 2 es muy baja y excelente. El código es lineal y fácil de entender en su flujo.
#
# ---
#
# ### 2. Evaluación (Acoplamiento y Sobreingeniería)
#
# *   **Acoplamiento:** El acoplamiento es **muy bajo**. La función es pura; solo depende de su entrada (`l`) y no interactúa con ningún estado externo ni tiene dependencias ocultas.
# *   **Sobreingeniería:** No hay sobreingeniería en el sentido de añadir capas o abstracciones innecesarias. La implementación es directa y simple.
#     *   **Sin embargo**, existe una función *built-in* en Python (`sum()`) que realiza exactamente la misma tarea de forma más concisa, legible y, a menudo, más eficiente. El código actual no es "malo", pero no es **idiomático** en Python.
#
# ---
#
# ### 3. Propuesta (Estructura Simplificada - Monolito Modular)
#
# Dada la extrema simplicidad de esta función, no hay una estructura compleja que simplificar a nivel arquitectónico. Esta función es una **utilidad básica**.
#
# En el contexto de un Monolito Modular, esta función se clasificaría como una **utilidad genérica** que no pertenece a un dominio de negocio específico (ej. `usuarios`, `pedidos`).
#
# *   **Ubicación Sugerida:** Se ubicaría idealmente en un módulo de `utils` o `helpers` dentro de una capa `core` o `shared` del monolito.
#     *   **Ejemplo de estructura:**
#         ```
#         my_monolith/
#         ├── core/
#         │   └── utils/
#         │       └── math_helpers.py  # Aquí iría esta función
#         ├── modules/
#         │   ├── users/
#         │   └── orders/
#         └── main.py
#         ```
# *   **Conclusión:** No requiere cambios estructurales a nivel de arquitectura, solo una ubicación lógica y coherente dentro de un sistema más grande.
#
# ---
#
# ### 4. Refactorización (Código Final)
#
# La refactorización se centrará en hacer el código más idiomático, legible y robusto, utilizando las características de Python.
#
# ```python
# from typing import Iterable, Union
#
# def sumar_lista(l: Iterable[Union[int, float]]) -> Union[int, float]:
#     """Suma todos los elementos numéricos de un iterable.
#
#     Esta función calcula la suma de todos los números contenidos en un iterable.
#     Utiliza la función built-in `sum()` de Python para una implementación
#     eficiente y legible, que es la forma idiomática de realizar esta operación.
#
#     Args:
#         l: Un iterable (por ejemplo, una lista, tupla o conjunto) que contiene
#            números enteros o de punto flotante.
#
#     Returns:
#         La suma total de los elementos. El tipo de retorno será entero si todos
#         los elementos y el valor inicial (por defecto 0) son enteros,
#         o de punto flotante si alguno de ellos es de punto flotante.
#     """
#     return sum(l)
# ```
